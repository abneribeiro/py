# %%
import os
import pandas as pd
#import matplotlib.pyplot as plt


lista_arquivo = os.listdir("./vendas_2")
tabela_total = pd.DataFrame()

for arquivo in lista_arquivo:

    if "Vendas" in arquivo:
        tabela = pd.read_csv(f"vendas_2\{arquivo}")
        tabela_total = tabela_total.append(tabela)
        
display(tabela_total)
# Out:
# C:\Users\AbneRibeiro\AppData\Local\Temp\ipykernel_3440\440374657.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela_total = tabela_total.append(tabela)
# C:\Users\AbneRibeiro\AppData\Local\Temp\ipykernel_3440\440374657.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela_total = tabela_total.append(tabela)
# C:\Users\AbneRibeiro\AppData\Local\Temp\ipykernel_3440\440374657.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela_total = tabela_total.append(tabela)
# C:\Users\AbneRibeiro\AppData\Local\Temp\ipykernel_3440\440374657.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
tabela_produtos = tabela_total.groupby('Produto').sum()
tabela_produtos = tabela_produtos[['Quantidade Vendida']].sort_values(by='Quantidade Vendida', ascending=False)
display(tabela_produtos)
# Out:
# Falha ao iniciar o Kernel.
#
# Não é possível iniciar o Kernel "base (Python 3.9.13)" devido ao tempo limite da conexão.
#
# Consulte o <a href='command:jupyter.viewOutput'>log</a> do Jupyter para obter mais detalhes.

# %%
tabela_total['faturamento'] = tabela_total['Quantidade Vendida'] * tabela_total['Preco Unitario']
tabela_faturemento= tabela_total.groupby('Produto').sum()
tabela_faturemento = tabela_faturemento[['faturamento']].sort_values(by='faturamento', ascending=False)
display(tabela_faturemento)
# Out:
# Falha ao iniciar o Kernel.
#
# Não é possível iniciar o Kernel "base (Python 3.9.13)" devido ao tempo limite da conexão.
#
# Consulte o <a href='command:jupyter.viewOutput'>log</a> do Jupyter para obter mais detalhes.

# %%
tabela_lojas = tabela_total.groupby('Loja').sum()
tabela_lojas = tabela_lojas[['faturamento']].sort_values(by='faturamento', ascending=False)
display(tabela_lojas)
# Out:
# Falha ao iniciar o Kernel.
#
# Não é possível iniciar o Kernel "base (Python 3.9.13)" devido ao tempo limite da conexão.
#
# Consulte o <a href='command:jupyter.viewOutput'>log</a> do Jupyter para obter mais detalhes.

# %%
import plotly.express as px

grafico = px.bar(tabela_lojas, x = tabela_lojas.index, y = 'faturamento')

grafico.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import plotly.express as px
# ----> 3 grafico = px.bar(tabela_lojas, x = tabela_lojas.index, y = 'faturamento')
#       5 grafico.show()
#
# NameError: name 'tabela_lojas' is not defined
