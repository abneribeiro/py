# %%
import pandas as pd

# %%
monitor = pd.read_csv("system_monitoring.csv")

# %%
monitor.head(20)
# Out:
#     cpu_count  cpu_freq  ram_total  ram_available  ram_used  swap_total  \
# 0         1.0    1795.0     3044.0         1516.0    1528.0      3072.0
# 1         NaN    1795.0        NaN            NaN       NaN         NaN
# 2         NaN    1795.0        NaN            NaN       NaN         NaN
# 3         NaN    1795.0        NaN            NaN       NaN         NaN
# 4         NaN    1795.0        NaN            NaN       NaN         NaN
# 5         NaN    1795.0        NaN            NaN       NaN         NaN
# 6         NaN    1795.0        NaN            NaN       NaN         NaN
# 7         NaN    1795.0        NaN            NaN       NaN         NaN
# 8         NaN    1795.0        NaN            NaN       NaN         NaN
# 9         NaN    1795.0        NaN            NaN       NaN         NaN
# 10        NaN    1795.0        NaN            NaN       NaN         NaN
# 11        NaN    1795.0        NaN            NaN       NaN         NaN
# ...

# %%
df_monitor = monitor["time"	,"cpu_percent"	,"ram_usage"	,"swap_usage"]
df_monitor
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Abneribeiro\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\Abneribeiro\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Abneribeiro\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
monitor.isnull().sum()
# Out:
# cpu_count        60
# cpu_freq          0
# ram_total        60
# ram_available    60
# ram_used         60
# swap_total       60
# swap_used        60
# time              1
# cpu_percent       1
# ram_usage         1
# swap_usage        1
# disk_usage        1
# dtype: int64
